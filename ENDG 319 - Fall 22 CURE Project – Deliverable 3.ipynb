# %%
import sklearn.datasets
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy
a = DataFrame()
a = sklearn.datasets.load_breast_cancer()

# %%
a.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print(a.feature_names)
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %%
print(a.target_names)
# Out:
# ['malignant' 'benign']

# %%
print(a.DESCR)
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         worst/largest values) of these features were computed for each image,
# ...

# %%
from sklearn.datasets import load_breast_cancer
breast_cancer = load_breast_cancer(return_X_y=True, as_frame=True)
breast_cancer[0], breast_cancer[1]
# Out:
# (     mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
#  0          17.99         10.38          122.80     1001.0          0.11840
#  1          20.57         17.77          132.90     1326.0          0.08474
#  2          19.69         21.25          130.00     1203.0          0.10960
#  3          11.42         20.38           77.58      386.1          0.14250
#  4          20.29         14.34          135.10     1297.0          0.10030
#  ..           ...           ...             ...        ...              ...
#  564        21.56         22.39          142.00     1479.0          0.11100
#  565        20.13         28.25          131.20     1261.0          0.09780
#  566        16.60         28.08          108.30      858.1          0.08455
#  567        20.60         29.33          140.10     1265.0          0.11780
#  568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
cancer = breast_cancer[0]
cancer['typeofcancer'] = breast_cancer[1]
cancer
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
cancer.shape
# Out:
# (569, 31)

# %%
df = cancer[['mean radius', 'mean perimeter', 'mean area', 'typeofcancer']]
df.head(2)
# Out:
#    mean radius  mean perimeter  mean area  typeofcancer
# 0        17.99           122.8     1001.0             0
# 1        20.57           132.9     1326.0             0

# %%
df.iloc[17:22]
# Out:
#     mean radius  mean perimeter  mean area  typeofcancer
# 17       16.130          108.10      798.8             0
# 18       19.810          130.00     1260.0             0
# 19       13.540           87.46      566.3             1
# 20       13.080           85.63      520.0             1
# 21        9.504           60.34      273.9             1

# %% [markdown]
# ## Task 2

# %% [markdown]
# Suppose we want to explore the possibility of developing a machine learning model that can diagnose a new patient’s cancer condition as benign or malignant from the features in df.
#
# (i) As a first step, you want to do some graphical analysis. Write the code to generate the following figure (Figure 1). Show screenshot of the code (input) and the figure (output) from your work. You are free to choose your favorite data marker and color in your figure.

# %%
sorted_df = df.sort_values('typeofcancer')
fig, axs = plt.subplots(figsize=(10, 2.5))
axs1 = plt.subplot2grid ( shape= (1,3), loc= (0,0) )
axs2 = plt.subplot2grid ( shape= (1,3), loc= (0,1) )
axs3 = plt.subplot2grid ( shape= (1,3), loc= (0,2) )
plt.tight_layout()

axs1.hist(sorted_df.iloc[0:212, 0], edgecolor='black', fc = 'none', label = 'c0 (Malignant)')
axs1.hist(sorted_df.iloc[212:569, 0], edgecolor='red', fc = 'none', label = 'c1 (Benign)')
axs1.set_xlabel('mean radius')
axs1.set_ylabel('frequency')
axs1.legend()

axs2.scatter(sorted_df.iloc[0:212, 1], sorted_df.iloc[0:212, 0], c='black', label = 'c0 (M)')
axs2.scatter(sorted_df.iloc[212:569, 1], sorted_df.iloc[212:569, 0], c='red', label = 'c1 (B)')
axs2.set_xlabel('mean perimeter')
axs2.set_ylabel('mean radius')
axs2.legend()

axs3.scatter(sorted_df.iloc[0:212, 2], sorted_df.iloc[0:212, 0], c='black', label = 'c0 (M)')
axs3.scatter(sorted_df.iloc[212:569, 2], sorted_df.iloc[212:569, 0], c='red', label = 'c1 (B)')
axs3.set_xlabel('mean area')
axs3.set_ylabel('mean radius')
axs3.legend()

# %% [markdown]
#     In the histogram we can see that there is a higher frequency of benign cancer compared to the malignant variety. Furthermore, the mean perimeter shows a linear progression with the malignant type of cancer having a superior value, in contrast, the mean area has an exponential progression though like the perimeter the malignant cancer has a larger value area on average.

# %% [markdown]
# It is evident that there are higher frequency of Benign cancer while Malignant variant has bigger mean radius. Fig 2 indicates that Malignant has bigger perimeter and radius thatn Benign. Lastly, the Belingn variant tend to have smaller area. In conclusion, Benign tends to be smaller that Malignant.

# %% [markdown]
# # Task 3

# %% [markdown]
# (i) Generate the following figure (Figure 2). Show screenshot(s) of the code (input) and the
# figure (output) from your work. You are free to choose your favorite data marker and color in
# your figure.

# %%
data_from_excel = pandas.read_excel('ENGG_319_Cure_3.xlsx')

# %%
data_from_excel
# Out:
#      Instance       Player Name Position  Age  Games Played  Minutes Played  \
# 0           1     Mikal Bridges  Forward   25            82            2854
# 1           2     Miles Bridges  Forward   23            80            2837
# 2           3     DeMar DeRozan  Forward   32            76            2743
# 3           4      Jayson Tatum  Forward   23            76            2731
# 4           5        Saddiq Bey  Forward   22            82            2704
# ..        ...               ...      ...  ...           ...             ...
# 267       268     Lamar Stevens  Forward   24            63            1015
# 268       269       Cam Reddish  Forward   22            49            1012
# 269       270  Donte DiVincenzo    Guard   25            42            1006
# 270       271   Wesley Matthews    Guard   35            49            1002
# 271       272  Payton Pritchard    Guard   24            71            1001
#
# ...

# %%
df1 = data_from_excel[['Position', 'Points']]
df1
sorteddf1= df1.pivot(columns="Position",values="Points")
plt.ylabel("Points")
plt.xlabel("Position")
plt.title("Points by Position")
sorteddf1.boxplot()
# Out:
# <AxesSubplot:title={'center':'Points by Position'}, xlabel='Position', ylabel='Points'>

# %%
df2 = data_from_excel[['Position', 'Rebounds']]
df2
sorteddf2= df2.pivot(columns="Position",values="Rebounds")
plt.ylabel("Points")
plt.xlabel("Rebounds")
plt.title("Points by Rebounds")
sorteddf2.boxplot()
# Out:
# <AxesSubplot:title={'center':'Points by Rebounds'}, xlabel='Rebounds', ylabel='Points'>

# %%
df3 = data_from_excel[['Position', 'Assists']]
df3
sorteddf3= df3.pivot(columns="Position",values="Assists")
plt.ylabel("Points")
plt.xlabel("Assists")
plt.title("Points by Assists")
sorteddf3.boxplot()
# Out:
# <AxesSubplot:title={'center':'Points by Assists'}, xlabel='Assists', ylabel='Points'>

# %%
df4 = data_from_excel[['Position', 'Assists']]


fig, axs = plt.subplots(figsize=(10, 2.5))
axs1 = plt.subplot2grid ( shape= (1,3), loc= (0,0) )
axs2 = plt.subplot2grid ( shape= (1,3), loc= (0,1) )
axs3 = plt.subplot2grid ( shape= (1,3), loc= (0,2) )
plt.tight_layout()

axs1.hist(sorteddf1.iloc[0:100, 0], edgecolor='black', fc = 'none', label = 'c0 (Malignant)')
axs1.legend()

# %%
axs2.scatter(sorteddf2.iloc[0:212, 1], sorted_df.iloc[0:212, 0], c='black', label = 'c0 (M)')
axs2.scatter(sorteddf2.iloc[212:569, 1], sorted_df.iloc[212:569, 0], c='red', label = 'c1 (B)')
axs2.legend()

axs3.scatter(sorteddf3.iloc[0:212, 2], sorted_df.iloc[0:212, 0], c='black', label = 'c0 (M)')
axs3.scatter(sorteddf3.iloc[212:569, 2], sorted_df.iloc[212:569, 0], c='red', label = 'c1 (B)')
axs3.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [82], in <cell line: 2>()
#       1 axs2.scatter(sorteddf2.iloc[0:212, 1], sorted_df.iloc[0:212, 0], c='black', label = 'c0 (M)')
# ----> 2 axs2.scatter(sorteddf2.iloc[212:569, 1], sorted_df.iloc[212:569, 0], c='red', label = 'c1 (B)')
#       3 axs2.legend()
#       5 axs3.scatter(sorteddf3.iloc[0:212, 2], sorted_df.iloc[0:212, 0], c='black', label = 'c0 (M)')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
# ...

# %%
df4 = data_from_excel[['Position', 'Minutes Played', 'effective Field Goal%', 'All-Star?']]
df4
# Out:
#     Position  Minutes Played  effective Field Goal% All-Star?
# 0    Forward            2854                  0.601         N
# 1    Forward            2837                  0.554         N
# 2    Forward            2743                  0.521         Y
# 3    Forward            2731                  0.526         Y
# 4    Forward            2704                  0.489         N
# ..       ...             ...                    ...       ...
# 267  Forward            1015                  0.517         N
# 268  Forward            1012                  0.485         N
# 269    Guard            1006                  0.461         N
# 270    Guard            1002                  0.516         N
# 271    Guard            1001                  0.564         N
#
# [272 rows x 4 columns]

# %%
df4superstars = df4.loc[['All-Star'] == "Y"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 df4superstars = df4.loc[['All-Star'] == "Y"]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1201, in _LocIndexer._getitem_axis(self, key, axis)
#    1198         return self.obj.iloc[tuple(indexer)]
#    1200 # fall thru to straight lookup
# -> 1201 self._validate_key(key, axis)
#    1202 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1011, in _LocIndexer._validate_key(self, key, axis)
#    1001 @doc(_LocationIndexer._validate_key)
# ...

# %% [markdown]
# Other Ideas
# Minutes played (X) against Total Points(Y). Separate All-stars vs non allstars by color, subplot for each position: Guard, Forward, Center.
#
# Minutes played (X) against Assists (Y). Separate All-stars vs non allstars by color, subplot for Guard, Forward, Center.
# Minutes played (X) against Rebounds(Y). Separate All-stars vs non allstars by color, subplot for Guard, Forward, Center.
