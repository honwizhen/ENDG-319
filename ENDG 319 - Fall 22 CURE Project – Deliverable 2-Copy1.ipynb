# %%
import sklearn.datasets
import pandas 
import matplotlib.pyplot as plt
a = DataFrame()
a = sklearn.datasets.load_breast_cancer()

# %% [markdown]
# # Task 1

# %% [markdown]
# Create a dataframe variable ‘a’ with this dataset. This dataframe should have all the 569 instances, 30 features and the class of 569 instances as 0 (Malignant) or 1 (Benign). The column
# that contains the classes should be labeled as ‘typeofcancer’. Show the output of the following input:

# %%
a.keys()

# %%
print(a.feature_names)
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %%
print(a.target_names)
# Out:
# ['malignant' 'benign']

# %%
print(a.DESCR)
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         worst/largest values) of these features were computed for each image,
# ...

# %%
from sklearn.datasets import load_breast_cancer
breast_cancer = load_breast_cancer(return_X_y=True, as_frame=True)
breast_cancer[0], breast_cancer[1]
# Out:
# (     mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
#  0          17.99         10.38          122.80     1001.0          0.11840
#  1          20.57         17.77          132.90     1326.0          0.08474
#  2          19.69         21.25          130.00     1203.0          0.10960
#  3          11.42         20.38           77.58      386.1          0.14250
#  4          20.29         14.34          135.10     1297.0          0.10030
#  ..           ...           ...             ...        ...              ...
#  564        21.56         22.39          142.00     1479.0          0.11100
#  565        20.13         28.25          131.20     1261.0          0.09780
#  566        16.60         28.08          108.30      858.1          0.08455
#  567        20.60         29.33          140.10     1265.0          0.11780
#  568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
cancer = breast_cancer[0]
cancer['typeofcancer'] = breast_cancer[1]
cancer
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
cancer.shape
# Out:
# (569, 31)

# %%
df = cancer[['mean radius', 'mean perimeter', 'mean area', 'typeofcancer']]
df.head(2)
# Out:
#    mean radius  mean perimeter  mean area  typeofcancer
# 0        17.99           122.8     1001.0             0
# 1        20.57           132.9     1326.0             0

# %%
df.iloc[17:22]
# Out:
#     mean radius  mean perimeter  mean area  typeofcancer
# 17       16.130          108.10      798.8             0
# 18       19.810          130.00     1260.0             0
# 19       13.540           87.46      566.3             1
# 20       13.080           85.63      520.0             1
# 21        9.504           60.34      273.9             1

# %% [markdown]
# ## Task 2

# %% [markdown]
# Suppose we want to explore the possibility of developing a machine learning model that can diagnose a new patient’s cancer condition as benign or malignant from the features in df.
#
# (i) As a first step, you want to do some graphical analysis. Write the code to generate the following figure (Figure 1). Show screenshot of the code (input) and the figure (output) from your work. You are free to choose your favorite data marker and color in your figure.

# %%
df = cancer[['mean radius', 'mean concavity', 'mean concave points', 'mean symmetry', 'typeofcancer']]
sorted_df = df.sort_values('typeofcancer')
sorted_df
# Out:
#      mean radius  mean concavity  mean concave points  mean symmetry  \
# 0          17.99         0.30010              0.14710         0.2419
# 190        14.22         0.19810              0.06618         0.2384
# 193        12.34         0.10850              0.04562         0.1943
# 194        14.86         0.16970              0.08878         0.1737
# 196        13.77         0.13850              0.06526         0.1834
# ..           ...             ...                  ...            ...
# 269        10.71         0.08448              0.02867         0.1668
# 268        12.87         0.03900              0.01615         0.2010
# 267        13.59         0.04072              0.02142         0.1635
# 281        11.74         0.02245              0.02763         0.2101
# 568         7.76         0.00000              0.00000         0.1587
#
#      typeofcancer
# 0               0
# 190             0
# 193             0
# 194             0
# 196             0
# ..            ...
# ...

# %%
sorted_df = df.sort_values('typeofcancer')
fig, axs = plt.subplots(figsize=(10, 2.5))
axs1 = plt.subplot2grid ( shape= (1,3), loc= (0,0) )
axs2 = plt.subplot2grid ( shape= (1,3), loc= (0,1) )
axs3 = plt.subplot2grid ( shape= (1,3), loc= (0,2) )
plt.tight_layout()

axs1.hist(sorted_df.iloc[0:212, 0], edgecolor='black', fc = 'none', label = 'c0 (Malignant)')
axs1.hist(sorted_df.iloc[212:569, 0], edgecolor='red', fc = 'none', label = 'c1 (Benign)')
axs1.set_xlabel('mean radius')
axs1.set_ylabel('frequency')
axs1.legend()

axs2.scatter(sorted_df.iloc[0:212, 1], sorted_df.iloc[0:212, 0], c='black', label = 'c0 (M)')
axs2.scatter(sorted_df.iloc[212:569, 1], sorted_df.iloc[212:569, 0], c='red', label = 'c1 (B)')
axs2.set_xlabel('mean perimeter')
axs2.set_ylabel('mean radius')
axs2.legend()

axs3.scatter(sorted_df.iloc[0:212, 2], sorted_df.iloc[0:212, 0], c='black', label = 'c0 (M)')
axs3.scatter(sorted_df.iloc[212:569, 2], sorted_df.iloc[212:569, 0], c='red', label = 'c1 (B)')
axs3.set_xlabel('mean area')
axs3.set_ylabel('mean radius')
axs3.legend()

# %% [markdown]
# (ii) It is evident that there are higher frequency of Benign cancer while Malignant variant has bigger mean radius. Fig 2 indicates that Malignant has bigger perimeter and radius thatn Benign. Lastly, the Belingn variant tend to have smaller area. In conclusion, Benign tends to be smaller that Malignant.

# %% [markdown]
# # Task 3

# %% [markdown]
# (i) Generate the following figure (Figure 2). Show screenshot(s) of the code (input) and the
# figure (output) from your work. You are free to choose your favorite data marker and color in
# your figure.

# %%
fig, axs = plt.subplots(figsize=(10, 2.5))
axs1 = plt.subplot2grid ( shape= (1,4), loc= (0,0) )
axs2 = plt.subplot2grid ( shape= (1,4), loc= (0,1) )
axs3 = plt.subplot2grid ( shape= (1,4), loc= (0,2) )
axs4 = plt.subplot2grid ( shape= (1,4), loc= (0,3) )
plt.tight_layout()

axs1.hist(sorted_df.iloc[0:212, 0], edgecolor='black', fc = 'none', label = 'c0 (M)')
axs1.hist(sorted_df.iloc[212:569, 0], edgecolor='red', fc = 'none', label = 'c1 (B)')
axs1.set_xlabel('mean radius')
axs1.set_ylabel('frequency')
axs1.legend()

axs2.scatter(sorted_df.iloc[0:212, 1], sorted_df.iloc[0:212, 0], c='purple', label = 'c0 (M)')
axs2.scatter(sorted_df.iloc[212:569, 1], sorted_df.iloc[212:569, 0], c='pink', label = 'c1 (B)')
axs2.set_xlabel('mean radius')
axs2.set_ylabel('mean concavity')
axs2.legend()

axs3.scatter(sorted_df.iloc[0:212, 2], sorted_df.iloc[0:212, 0], c='purple', label = 'c0 (M)')
axs3.scatter(sorted_df.iloc[212:569, 2], sorted_df.iloc[212:569, 0], c='pink', label = 'c1 (B)')
axs3.set_xlabel('mean radius')
axs3.set_ylabel('mean concave points')
axs3.legend()

axs4.scatter(sorted_df.iloc[0:212, 3], sorted_df.iloc[0:212, 0], c='purple', label = 'c0 (M)')
axs4.scatter(sorted_df.iloc[212:569, 3], sorted_df.iloc[212:569, 0], c='pink', label = 'c1 (B)')
axs4.set_xlabel('mean radius')
axs4.set_ylabel('mean symmetry')
axs4.legend()

# %% [markdown]
# (ii) Fig. 1 is the same as the previous. Fig. 2 indicates that malignant has bigger radius and concavity. The next one proves that Malignant a higher concave points. Last but not least, the last figure indicates that the are higher values of symmetry.

# %% [markdown]
# # Task 4

# %% [markdown]
# Think of a classification problem from your own experience and interest (e.g., distinguishing between two types of things/livingbeings/weather/personality/vehicle/industry/sports/houses/professionals etc.). Collect some real-
# world data to solve that classification problem. Have at least two classes, two attributes and at
# least 5 instances per class. Create a dataframe with this data and paste a screenshot of it. Also
# give a short description of the data (number of instances, number of attributes and the list of
# attributes, list of classes, and creator: Your name). The attributes should be numerical.
#
# The classification problem should be a new one, but the dataset may contain data that are new (generated by you by any rough measurements) or collected from public domain. Please cite the references/sources from which you collect the data.

# %%
Personalities = DataFrame()
Personalities['Name'] = ['Architect', 'Logician', 'Commander', 'Debater', 'Advocate', 'Mediator', 'Protagonist', 'Campaigner', 'Logistician', 'Defender', 'Executive', 'Consul', 'Virtuoso', 'Adventurer', 'Entrepreneur', 'Entertainer']
Personalities['Code'] = ['INTJ', 'INTP', 'ENTJ', 'ENTP', 'INFJ', 'INFP', 'ENFJ', 'ENFP', 'ISTJ', 'ISFJ', 'ESTJ', 'ESFJ', 'ISTP', 'ISFP', 'ESTP', 'ESFP']
Personalities['Distribution (%)']= [2.1, 3.3, 1.8, 3.2, 1.5, 4.4, 2.5, 8.1, 11.6, 13.8, 8.7, 12, 5.4, 8.8, 4.3, 8.5] 
Personalities['Male (%)'] = [3.3, 4.8, 2.7, 4.0, 1.2, 4.1, 1.6, 6.4, 16.4, 8.1, 11.2, 7.5, 8.5, 7.6, 5.6, 6.9]
Personalities['Female (%)'] = [0.9, 1.7, 0.9, 2.4, 1.6, 4.6, 3.3, 9.7, 6.9, 19.4, 6.3, 16.9, 2.3, 9.9, 3.0, 10.1]
Personalities['Mind'] = ['Introverted', 'Introverted', 'Extroverted', 'Extroverted', 'Introverted', 'Introverted', 'Extroverted', 'Extroverted', 'Introverted', 'Introverted', 'Extroverted', 'Extroverted', 'Introverted', 'Introverted', 'Extroverted', 'Extroverted']
Personalities['Energy'] = ['Intuitive', 'Intuitive', 'Intuitive', 'Intuitive', 'Intuitive', 'Intuitive', 'Intuitive', 'Intuitive', 'Sensing', 'Sensing', 'Sensing', 'Sensing', 'Sensing', 'Sensing', 'Sensing', 'Sensing',]
Personalities['Nature'] = ['Thinking', 'Thinking', 'Thinking', 'Thinking', 'Feeling', 'Feeling', 'Feeling', 'Feeling', 'Thinking', 'Thinking', 'Thinking', 'Thinking', 'Feeling', 'Feeling', 'Feeling', 'Feeling']
Personalities['Tactics'] = ['Judging', 'Prospecting', 'Judging', 'Prospecting', 'Judging', 'Prospecting', 'Judging', 'Prospecting', 'Judging', 'Prospecting', 'Judging', 'Prospecting', 'Judging', 'Prospecting', 'Judging', 'Prospecting']
Personalities
# Out:
#             Name  Code  Distribution (%)  Male (%)  Female (%)         Mind  \
# 0      Architect  INTJ               2.1       3.3         0.9  Introverted
# 1       Logician  INTP               3.3       4.8         1.7  Introverted
# 2      Commander  ENTJ               1.8       2.7         0.9  Extroverted
# 3        Debater  ENTP               3.2       4.0         2.4  Extroverted
# 4       Advocate  INFJ               1.5       1.2         1.6  Introverted
# 5       Mediator  INFP               4.4       4.1         4.6  Introverted
# 6    Protagonist  ENFJ               2.5       1.6         3.3  Extroverted
# 7     Campaigner  ENFP               8.1       6.4         9.7  Extroverted
# 8    Logistician  ISTJ              11.6      16.4         6.9  Introverted
# 9       Defender  ISFJ              13.8       8.1        19.4  Introverted
# 10     Executive  ESTJ               8.7      11.2         6.3  Extroverted
# ...

# %% [markdown]
# Number of instances: 16
# Number of numerical attributes: 3
# Number of classes: 5
# List of numerical attributes: 'Distribution', 'Male', 'Female'
# List of classes: 'Code', 'Mind', 'Energy', 'Nature', 'Tactics'
# Creator: Honwi Zhen
# Sources: 'https://personalitymax.com/personality-types/population-gender/', 'https://www.16personalities.com/personality-types'
